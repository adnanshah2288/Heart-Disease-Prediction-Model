# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanshah2288/Heart-Disease-Prediction-Model/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import Libraries !

import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# # FEATURE ENGINEERING !

# %%
# Importing Data

df = pd.DataFrame(pd.read_csv('Pateint_Dataset'))
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Handling Missing Values !

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
df = pd.DataFrame(imputer.fit_transform(df),columns=df.columns)

df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# Defining X and Y

X = df.drop(columns=['target'])
y = df['target']

# %%
X
# Out:
#        age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52.0  1.0  0.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1     53.0  1.0  0.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2     70.0  1.0  0.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3     61.0  1.0  0.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4     62.0  0.0  0.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 1020  59.0  1.0  1.0     140.0  221.0  0.0      1.0    164.0    1.0      0.0
# 1021  60.0  1.0  0.0     125.0  258.0  0.0      0.0    141.0    1.0      2.8
# 1022  47.0  1.0  0.0     110.0  275.0  0.0      0.0    118.0    1.0      1.0
# 1023  50.0  0.0  0.0     110.0  254.0  0.0      0.0    159.0    0.0      0.0
# 1024  54.0  1.0  0.0     120.0  188.0  0.0      1.0    113.0    0.0      1.4
#
#       slope   ca  thal
# ...

# %%
# Scalling

from sklearn.preprocessing import StandardScaler
Scaller = StandardScaler()
X = pd.DataFrame(Scaller.fit_transform(X),columns=X.columns)

# %% [markdown]
# # TRAINING MODEL !

# %%
# Spliting Data Into Training And Test Sets !

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state = 0)

# %%
# Modeling

from sklearn.neighbors import KNeighborsClassifier
Classifier = KNeighborsClassifier(n_neighbors=6,p=2,metric='minkowski')
Classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %% [markdown]
# # TESTING MODEL AND CHECKING IT'S ACCURACY !

# %%
y_pred = Classifier.predict(x_test)

# %%
# Accuracy Score Checking !

from sklearn.metrics import accuracy_score,confusion_matrix
print(f'Confussion Matrix {confusion_matrix(y_test,y_pred)}')
print(f'Accuracy Score {accuracy_score(y_test,y_pred)}')
# Out:
# Confussion Matrix [[111  12]
#  [ 20 114]]
# Accuracy Score 0.8754863813229572

# %%
X
# Out:
#            age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    -0.268437  0.661504 -0.915755 -0.377636 -0.659332 -0.418878  0.891255
# 1    -0.158157  0.661504 -0.915755  0.479107 -0.833861  2.387330 -1.004049
# 2     1.716595  0.661504 -0.915755  0.764688 -1.396233 -0.418878  0.891255
# 3     0.724079  0.661504 -0.915755  0.936037 -0.833861 -0.418878  0.891255
# 4     0.834359 -1.511706 -0.915755  0.364875  0.930822  2.387330  0.891255
# ...        ...       ...       ...       ...       ...       ...       ...
# 1020  0.503520  0.661504  0.055931  0.479107 -0.484803 -0.418878  0.891255
# 1021  0.613800  0.661504 -0.915755 -0.377636  0.232705 -0.418878 -1.004049
# 1022 -0.819834  0.661504 -0.915755 -1.234378  0.562371 -0.418878 -1.004049
# 1023 -0.488996 -1.511706 -0.915755 -1.234378  0.155137 -0.418878 -1.004049
# 1024 -0.047877  0.661504 -0.915755 -0.663216 -1.124743 -0.418878  0.891255
#
#        thalach     exang   oldpeak     slope        ca      thal
# ...

# %%
# DataSet Review !
df
# Out:
#        age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52.0  1.0  0.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1     53.0  1.0  0.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2     70.0  1.0  0.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3     61.0  1.0  0.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4     62.0  0.0  0.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 1020  59.0  1.0  1.0     140.0  221.0  0.0      1.0    164.0    1.0      0.0
# 1021  60.0  1.0  0.0     125.0  258.0  0.0      0.0    141.0    1.0      2.8
# 1022  47.0  1.0  0.0     110.0  275.0  0.0      0.0    118.0    1.0      1.0
# 1023  50.0  0.0  0.0     110.0  254.0  0.0      0.0    159.0    0.0      0.0
# 1024  54.0  1.0  0.0     120.0  188.0  0.0      1.0    113.0    0.0      1.4
#
#       slope   ca  thal  target
# ...

# %%
#  Creating  New Data As Input For New users

new_data = pd.DataFrame([{
    'age': input('Enter your Age : ?'),
    'sex': input('Enter your Sex : ?'),
    'cp': input('Enter your Chest Pain Type : ?'),
    'trestbps': input('Enter your Resting Blood Pressure (in mm Hg) : ?'),
    'chol': input('Enter your Serum Cholesterol (in mg/dL) : ?'),
    'fbs': input('Enter your Fasting Blood Sugar (1 = > 120 mg/dL, 0 = <= 120 mg/dL) : ?'),
    'restecg': input('Enter your Resting Electrocardiographic Results (0 = Normal, 1 = ST-T wave abnormality, 2 = Left Ventricular Hypertrophy) : ?'),
    'thalach': input('Enter your Maximum Heart Rate Achieved : ?'),
    'exang': input('Enter your Exercise Induced Angina (1 = Yes, 0 = No) : ?'),
    'oldpeak': input('Enter your ST Depression Induced by Exercise Relative to Rest : ?'),
    'slope': input('Enter your 	Slope of the Peak Exercise ST Segment (0 = Upsloping, 1 = Flat, 2 = Downsloping) : ?'),
    'ca': input('Enter your Number of Major Vessels Colored by Fluoroscopy (0–3) : ?'),
    'thal':input('Enter your Thalassemia (1 = Normal, 2 = Fixed Defect, 3 = Reversible Defect) : ?')
}])

## Scaling New Data with Previously Created Scaller Object !

new_data = pd.DataFrame(Scaller.fit_transform(new_data),columns=new_data.columns,dtype=float)

# Make a prediction
pred = Classifier.predict(new_data)

if pred == 1:
    ans = 'Heart Disease Present'
else:
    ans = 'No Heart Disease'

print(f'Result : {ans}')
# Out:
# Enter your Sex : ?23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-eb56e211e106> in <cell line: 0>()
#       4     'age': input('Enter your Age : ?'),
#       5     'sex': input('Enter your Sex : ?'),
# ----> 6     'cp': input('Enter your Chest Pain Type : ?'),
#       7     'trestbps': input('Enter your Resting Blood Pressure (in mm Hg) : ?'),
#       8     'chol': input('Enter your Serum Cholesterol (in mg/dL) : ?'),
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...
